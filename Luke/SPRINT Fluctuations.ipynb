# %%
import pandas as pd
import csv

##Calculation for EC + carbonate. 

data = pd.read_csv('COLVAR', sep=' ', header=None)
data.columns = ['NaN','time','rg','sp1','sp2','sp3','sp4','sp5','sp6','sp7','sp8','sp9','sp10','sp11','sp12','sp13','sp14','sp15','sp16','sp17','sp18','sp19','sp20','sp21','sp22','sp23','wall.bias','wall.force2']

#with open("COLVAR") as f:
#   reader = csv.reader(f)
#   print(next(reader)[0])
#print(data['sp1'])

print(data)
# Out:
#     NaN  time        rg       sp1       sp2       sp3       sp4       sp5  \
# 0   NaN  0.01  0.421809  7.512875  9.251806  9.194666  1.193142  1.172825
# 1   NaN  0.02  0.421627  7.482399  9.339198  9.195900  1.048812  1.079833
# 2   NaN  0.03  0.417368  7.607556  9.611161  9.657600  0.945004  0.948812
# 3   NaN  0.04  0.414993  7.703287  9.316828  9.462827  1.470776  1.356327
# 4   NaN  0.05  0.414866  7.577021  9.261302  9.201363  1.846604  1.738410
# 5   NaN  0.06  0.411189  7.710957  9.564771  9.443011  1.393817  1.349277
# 6   NaN  0.07  0.408101  7.759059  9.322488  9.327923  1.533442  1.447030
# 7   NaN  0.08  0.406719  6.882194  8.252146  8.306171  3.857434  3.405813
# 8   NaN  0.09  0.403090  7.283211  8.736365  8.838074  3.461441  3.191294
# 9   NaN  0.10  0.400507  7.792117  9.272295  9.276347  2.235598  2.196933
# 10  NaN  0.11  0.400452  7.325918  8.622753  8.526117  3.440081  3.385846
# 11  NaN  0.12  0.399465  7.184390  8.498597  8.466794  3.559052  3.517856
# ...

# %%
import pandas as pd
import csv

##Calculation for EC + PC. PC is cyclic to prevent loss of methyl group. 

data = pd.read_csv('COLVAR', sep=' ', header=None)
data.columns = ['NaN','time','rg','sp1','sp2','sp3','sp4','sp5','sp6','sp7','sp8','sp9','sp10','sp11','sp12','sp13','sp14','sp15','sp16','sp17','sp18','sp19','sp20','sp21','sp22','sp23','wall.bias','wall.force2']

#with open("COLVAR") as f:
#   reader = csv.reader(f)
#   print(next(reader)[0])
#print(data['sp1'])

print(data)
