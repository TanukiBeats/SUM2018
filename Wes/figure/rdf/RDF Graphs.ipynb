# %%
import numpy as np
import matplotlib.pyplot as plt

x, y = [], []

with open("C16_A16.xvg") as f:
    for line in f:
        cols = line.split()

        if len(cols) == 2:
            x.append(float(cols[0]))
            y.append(float(cols[1]))


fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.set_title("BMI_TF2 RDF Calculation")    
ax1.set_xlabel('X label?')
ax1.set_ylabel('Y label?')
ax1.plot(x,y, c='r', label='IMPORTANT DATA')
leg = ax1.legend()
plt.xlim(xmin=0.1,xmax=0.3)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x, y = [], []

with open("C17_A17.xvg") as f:
    for line in f:
        cols = line.split()

        if len(cols) == 2:
            x.append(float(cols[0]))
            y.append(float(cols[1]))


fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.set_title("BMI_TF2 RDF Calculation")    
ax1.set_xlabel('X label?')
ax1.set_ylabel('Y label?')
ax1.plot(x,y, c='r', label='IMPORTANT DATA')
leg = ax1.legend()
plt.xlim(xmin=0.1,xmax=0.3)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x, y = [], []

with open("C18_A18.xvg") as f:
    for line in f:
        cols = line.split()

        if len(cols) == 2:
            x.append(float(cols[0]))
            y.append(float(cols[1]))


fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.set_title("BMI_TF2 RDF Calculation")    
ax1.set_xlabel('X label?')
ax1.set_ylabel('Y label?')
ax1.plot(x,y, c='r', label='IMPORTANT DATA')
leg = ax1.legend()
plt.xlim(xmin=0.1,xmax=0.3)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x, y = [], []

with open("C19_A19.xvg") as f:
    for line in f:
        cols = line.split()

        if len(cols) == 2:
            x.append(float(cols[0]))
            y.append(float(cols[1]))


fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.set_title("BMI_TF2 RDF Calculation")    
ax1.set_xlabel('X label?')
ax1.set_ylabel('Y label?')
ax1.plot(x,y, c='r', label='IMPORTANT DATA')
leg = ax1.legend()
plt.xlim(xmin=0.1,xmax=0.3)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x, y = [], []

with open("C25_A25.xvg") as f:
    for line in f:
        cols = line.split()

        if len(cols) == 2:
            x.append(float(cols[0]))
            y.append(float(cols[1]))


fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.set_title("BMI_TF2 RDF Calculation")    
ax1.set_xlabel('X label?')
ax1.set_ylabel('Y label?')
ax1.plot(x,y, c='r', label='IMPORTANT DATA')
leg = ax1.legend()
plt.xlim(xmin=0.1,xmax=0.3)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x, y = [], []

with open("C26_A26.xvg") as f:
    for line in f:
        cols = line.split()

        if len(cols) == 2:
            x.append(float(cols[0]))
            y.append(float(cols[1]))


fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.set_title("BMI_TF2 RDF Calculation")    
ax1.set_xlabel('X label?')
ax1.set_ylabel('Y label?')
ax1.plot(x,y, c='r', label='IMPORTANT DATA')
leg = ax1.legend()
plt.xlim(xmin=0.1,xmax=0.3)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x, y = [], []

with open("BMI_TF2.xvg") as f:
    for line in f:
        cols = line.split()

        if len(cols) == 2:
            x.append(float(cols[0]))
            y.append(float(cols[1]))


fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.set_title("BMI_TF2 RDF Calculation")    
ax1.set_xlabel('X label?')
ax1.set_ylabel('Y label?')
ax1.plot(x,y, c='r', label='IMPORTANT DATA')
leg = ax1.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x, y = [], []

with open("C79_A79.xvg") as f:
    for line in f:
        cols = line.split()

        if len(cols) == 2:
            x.append(float(cols[0]))
            y.append(float(cols[1]))


fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.set_title("BMI_TF2 RDF Calculation")    
ax1.set_xlabel('X label?')
ax1.set_ylabel('Y label?')
ax1.plot(x,y, c='r', label='IMPORTANT DATA')
leg = ax1.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-ec667b128e49> in <module>()
#       4 x, y = [], []
#       5
# ----> 6 with open("C79_A79.xvg") as f:
#       7     for line in f:
#       8         cols = line.split()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C79_A79.xvg'
